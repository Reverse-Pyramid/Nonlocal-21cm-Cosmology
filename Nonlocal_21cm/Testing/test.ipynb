# %% [markdown]
# # Nonlocal Gravity
# ---

# %% [markdown]
# ### $\phi$ and $\dot{\phi}$ reults

# %%
include("../src/ParamsFunctions.jl")
import .ParamsFunctions as PF

# %%
PF.plot_phi(1000)
PF.plot_phi!(1200)

# %% [markdown]
# ### D results

# %%
PF.plot_d(1000)
PF.plot_d!(1200)
