# %% [markdown]
# # Nonlocal Gravity
# ---

# %% [markdown]
# ### $\phi$ and $\dot{\phi}$ reults

# %%
include("../src/ParamsFunctions.jl")
import .ParamsFunctions as PF
# Out:
# WARNING: replacing module ParamsFunctions.

# %%
PF.plot_phi(100)
PF.plot_phi!(1000)

# %% [markdown]
# ### D results

# %%
PF.plot_d(10000)
PF.plot_d!(0.00001)
